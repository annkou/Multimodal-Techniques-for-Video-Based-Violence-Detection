# %% [markdown]
# ### Import Libraries

# %%
import importlib
import os
import json
import sys
import pandas as pd

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "../..")))

from models import qwen

importlib.reload(qwen)

# %%
BATCH_SIZE = 4  # Small number to avoid RPM, TPM limits
QWEN_OUTPUT_JSON_PATH = "../../data/results/qwen_dashscope_results.json"
QWEN_METADATA_OUTPUT_JSON_PATH = "../../data/results/qwen_dashscope_metadata.json"
SYSTEM_PROMPT_PATH = "../../data/prompts/video_understanding_qwen_system.txt"
USER_PROMPT_PATH = "../../data/prompts/video_understanding_qwen_user.txt"

# %% [markdown]
# ### Get list with video urls

# %%
video_urls_path = "../../data/metadata/video_links_labels.csv"
video_urls = pd.read_csv(video_urls_path)
video_urls.head(3)
# Out:
#                                                   id  \
# 0  A.Beautiful.Mind.2001__#00-01-45_00-02-50_label_A
# 1  A.Beautiful.Mind.2001__#00-03-00_00-04-05_label_A
# 2  A.Beautiful.Mind.2001__#00-04-20_00-05-35_label_A
#
#                                         download_url  binary_label multilabel
# 0  https://huggingface.co/datasets/jherng/xd-viol...             0          0
# 1  https://huggingface.co/datasets/jherng/xd-viol...             0          0
# 2  https://huggingface.co/datasets/jherng/xd-viol...             0          0

# %%
video_urls_list = video_urls["download_url"].to_list()
video_urls_list[2]
# Out:
# 'https://huggingface.co/datasets/jherng/xd-violence/resolve/main/data/video/1-1004/A.Beautiful.Mind.2001__%2300-04-20_00-05-35_label_A.mp4'

# %% [markdown]
# ### Run Qwen

# %%
# Get prompt
with open(SYSTEM_PROMPT_PATH, "r", encoding="utf-8") as f:
    system_prompt = f.read()
with open(USER_PROMPT_PATH, "r", encoding="utf-8") as f:
    user_prompt = f.read()

# %%
# Initiate instance
qwen_model = qwen.QwenAsyncRequester(
    dashcope_api_key=os.getenv("DASHSCOPE_API_KEY"),
    together_api_key=os.getenv("TOGETHER_API_KEY"),
    model_name="qwen3-vl-235b-a22b-instruct",
)

# %%
async def call_qwen(video_urls_list, batch_size):
    for i in range(0, len(video_urls_list), BATCH_SIZE):
        batch = video_urls_list[i : i + BATCH_SIZE]
        print(f"Processing batch {i // BATCH_SIZE + 1} ({len(batch)} videos)...")
        results = await qwen_model.process_videos(
            video_urls=batch,
            system_prompt=system_prompt,
            user_prompt=user_prompt,
            batch_size=batch_size,  # concurrency within each batch
            output_json=QWEN_OUTPUT_JSON_PATH,
            overwrite=False,
            append=True,
        )
        print(f"Batch {i // BATCH_SIZE + 1} done, {len(results)} results appended.")

    print("All batches processed. Results saved in:", QWEN_OUTPUT_JSON_PATH)

# %%
await call_qwen(video_urls_list, batch_size=2)
# Out:
# Processing batch 1 (4 videos)...
# Batch 1 done, 3494 results appended.
# Processing batch 2 (4 videos)...
# Batch 2 done, 3498 results appended.
# Processing batch 3 (4 videos)...
# Batch 3 done, 3502 results appended.
# Processing batch 4 (4 videos)...
# Batch 4 done, 3506 results appended.
# Processing batch 5 (4 videos)...
# Batch 5 done, 3510 results appended.
# Processing batch 6 (4 videos)...
# Batch 6 done, 3514 results appended.
# Processing batch 7 (4 videos)...
# Batch 7 done, 3518 results appended.
# Processing batch 8 (4 videos)...
# Batch 8 done, 3522 results appended.
# Processing batch 9 (4 videos)...
# Batch 9 done, 3526 results appended.
# Processing batch 10 (4 videos)...
# Batch 10 done, 3530 results appended.
# Processing batch 11 (4 videos)...
# Batch 11 done, 3534 results appended.
# Processing batch 12 (4 videos)...
# Batch 12 done, 3538 results appended.
# Processing batch 13 (4 videos)...
# Batch 13 done, 3542 results appended.
# Processing batch 14 (4 videos)...
# Batch 14 done, 3546 results appended.
# Processing batch 15 (4 videos)...
# Batch 15 done, 3550 results appended.
# Processing batch 16 (4 videos)...
# Batch 16 done, 3554 results appended.
# Processing batch 17 (4 videos)...
# Batch 17 done, 3558 results appended.
# Processing batch 18 (4 videos)...
# Batch 18 done, 3562 results appended.
# Processing batch 19 (4 videos)...
# Batch 19 done, 3566 results appended.
# Processing batch 20 (4 videos)...
# Batch 20 done, 3570 results appended.
# Processing batch 21 (4 videos)...
# Batch 21 done, 3574 results appended.
# Processing batch 22 (4 videos)...
# Batch 22 done, 3578 results appended.
# Processing batch 23 (4 videos)...
# Batch 23 done, 3582 results appended.
# Processing batch 24 (4 videos)...
# Batch 24 done, 3586 results appended.
# Processing batch 25 (4 videos)...
# Batch 25 done, 3590 results appended.
# Processing batch 26 (4 videos)...
# Batch 26 done, 3594 results appended.
# Processing batch 27 (4 videos)...
# Batch 27 done, 3598 results appended.
# Processing batch 28 (4 videos)...
# Batch 28 done, 3602 results appended.
# Processing batch 29 (4 videos)...
# Batch 29 done, 3606 results appended.
# Processing batch 30 (4 videos)...
# Batch 30 done, 3610 results appended.
# Processing batch 31 (4 videos)...
# Batch 31 done, 3614 results appended.
# Processing batch 32 (4 videos)...
# Batch 32 done, 3618 results appended.
# Processing batch 33 (4 videos)...
# Batch 33 done, 3622 results appended.
# Processing batch 34 (4 videos)...
# Batch 34 done, 3626 results appended.
# Processing batch 35 (4 videos)...
# Batch 35 done, 3630 results appended.
# Processing batch 36 (4 videos)...
# Batch 36 done, 3634 results appended.
# Processing batch 37 (4 videos)...
# Batch 37 done, 3638 results appended.
# Processing batch 38 (4 videos)...
# Batch 38 done, 3642 results appended.
# Processing batch 39 (4 videos)...
# Batch 39 done, 3646 results appended.
# Processing batch 40 (4 videos)...
# Batch 40 done, 3650 results appended.
# Processing batch 41 (4 videos)...
# Batch 41 done, 3654 results appended.
# Processing batch 42 (4 videos)...
# Batch 42 done, 3658 results appended.
# Processing batch 43 (4 videos)...
# Batch 43 done, 3662 results appended.
# Processing batch 44 (4 videos)...
# Batch 44 done, 3666 results appended.
# Processing batch 45 (4 videos)...
# Batch 45 done, 3670 results appended.
# Processing batch 46 (4 videos)...
# Batch 46 done, 3674 results appended.
# Processing batch 47 (4 videos)...
# Batch 47 done, 3678 results appended.
# Processing batch 48 (4 videos)...
# Batch 48 done, 3682 results appended.
# Processing batch 49 (4 videos)...
# Batch 49 done, 3686 results appended.
# Processing batch 50 (4 videos)...
# Batch 50 done, 3690 results appended.
# Processing batch 51 (4 videos)...
# Batch 51 done, 3694 results appended.
# Processing batch 52 (4 videos)...
# Batch 52 done, 3698 results appended.
# Processing batch 53 (4 videos)...
# Batch 53 done, 3702 results appended.
# Processing batch 54 (4 videos)...
# Batch 54 done, 3706 results appended.
# Processing batch 55 (4 videos)...
# Batch 55 done, 3710 results appended.
# Processing batch 56 (4 videos)...
# Batch 56 done, 3714 results appended.
# Processing batch 57 (4 videos)...
# Batch 57 done, 3718 results appended.
# Processing batch 58 (4 videos)...
# Batch 58 done, 3722 results appended.
# Processing batch 59 (4 videos)...
# Batch 59 done, 3726 results appended.
# Processing batch 60 (4 videos)...
# Batch 60 done, 3730 results appended.
# Processing batch 61 (4 videos)...
# Batch 61 done, 3734 results appended.
# Processing batch 62 (4 videos)...
# Batch 62 done, 3738 results appended.
# Processing batch 63 (4 videos)...
# Batch 63 done, 3742 results appended.
# Processing batch 64 (4 videos)...
# Batch 64 done, 3746 results appended.
# Processing batch 65 (4 videos)...
# Batch 65 done, 3750 results appended.
# Processing batch 66 (4 videos)...
# Batch 66 done, 3754 results appended.
# Processing batch 67 (4 videos)...
# Batch 67 done, 3758 results appended.
# Processing batch 68 (4 videos)...
# Batch 68 done, 3762 results appended.
# Processing batch 69 (4 videos)...
# Batch 69 done, 3766 results appended.
# Processing batch 70 (4 videos)...
# Batch 70 done, 3770 results appended.
# Processing batch 71 (4 videos)...
# Batch 71 done, 3774 results appended.
# Processing batch 72 (4 videos)...
# Batch 72 done, 3778 results appended.
# Processing batch 73 (4 videos)...
# Batch 73 done, 3782 results appended.
# Processing batch 74 (4 videos)...
# Batch 74 done, 3786 results appended.
# Processing batch 75 (4 videos)...
# Batch 75 done, 3790 results appended.
# Processing batch 76 (4 videos)...
# Batch 76 done, 3794 results appended.
# Processing batch 77 (4 videos)...
# Batch 77 done, 3798 results appended.
# Processing batch 78 (4 videos)...
# Batch 78 done, 3802 results appended.
# Processing batch 79 (4 videos)...
# Batch 79 done, 3806 results appended.
# Processing batch 80 (4 videos)...
# Batch 80 done, 3810 results appended.
# Processing batch 81 (4 videos)...
# Batch 81 done, 3814 results appended.
# Processing batch 82 (4 videos)...
# Batch 82 done, 3818 results appended.
# Processing batch 83 (4 videos)...
# Batch 83 done, 3822 results appended.
# Processing batch 84 (4 videos)...
# Batch 84 done, 3826 results appended.
# Processing batch 85 (4 videos)...
# Batch 85 done, 3830 results appended.
# Processing batch 86 (4 videos)...
# Batch 86 done, 3834 results appended.
# Processing batch 87 (4 videos)...
# Batch 87 done, 3838 results appended.
# Processing batch 88 (4 videos)...
# Batch 88 done, 3842 results appended.
# Processing batch 89 (4 videos)...
# Batch 89 done, 3846 results appended.
# Processing batch 90 (4 videos)...
# Batch 90 done, 3850 results appended.
# Processing batch 91 (4 videos)...
# Batch 91 done, 3854 results appended.
# Processing batch 92 (4 videos)...
# Batch 92 done, 3858 results appended.
# Processing batch 93 (4 videos)...
# Batch 93 done, 3862 results appended.
# Processing batch 94 (4 videos)...
# Batch 94 done, 3866 results appended.
# Processing batch 95 (4 videos)...
# Batch 95 done, 3870 results appended.
# Processing batch 96 (4 videos)...
# Batch 96 done, 3874 results appended.
# Processing batch 97 (4 videos)...
# Batch 97 done, 3878 results appended.
# Processing batch 98 (4 videos)...
# Batch 98 done, 3882 results appended.
# Processing batch 99 (4 videos)...
# Batch 99 done, 3886 results appended.
# Processing batch 100 (4 videos)...
# Batch 100 done, 3890 results appended.
# Processing batch 101 (4 videos)...
# Batch 101 done, 3894 results appended.
# Processing batch 102 (4 videos)...
# Batch 102 done, 3898 results appended.
# Processing batch 103 (4 videos)...
# Batch 103 done, 3902 results appended.
# Processing batch 104 (4 videos)...
# Batch 104 done, 3906 results appended.
# Processing batch 105 (4 videos)...
# Batch 105 done, 3910 results appended.
# Processing batch 106 (4 videos)...
# Batch 106 done, 3914 results appended.
# Processing batch 107 (4 videos)...
# Batch 107 done, 3918 results appended.
# Processing batch 108 (4 videos)...
# Batch 108 done, 3922 results appended.
# Processing batch 109 (4 videos)...
# Batch 109 done, 3926 results appended.
# Processing batch 110 (4 videos)...
# Batch 110 done, 3930 results appended.
# Processing batch 111 (4 videos)...
# Batch 111 done, 3934 results appended.
# Processing batch 112 (4 videos)...
# Batch 112 done, 3938 results appended.
# Processing batch 113 (4 videos)...
# Batch 113 done, 3942 results appended.
# Processing batch 114 (4 videos)...
# Batch 114 done, 3946 results appended.
# Processing batch 115 (4 videos)...
# Batch 115 done, 3950 results appended.
# All batches processed. Results saved in: ../../data/results/qwen_dashscope_results.json

# %%
# Load the original results JSON
with open(QWEN_OUTPUT_JSON_PATH, "r", encoding="utf-8") as f:
    all_results = json.load(f)


# Filter: keep entries without errors OR with "data_inspection_failed" error
def should_keep_entry(entry):
    # Keep if no error
    if "error" not in entry or not entry["error"]:
        return True

    # Keep if error is "data_inspection_failed"
    error_text = entry.get("error", "")
    if "data_inspection_failed" in error_text or "inappropriate content" in error_text:
        return True

    # Discard all other errors
    return False


clean_results = [r for r in all_results if should_keep_entry(r)]

# Save the clean results to a new JSON file
CLEAN_JSON_PATH = "../../data/results/qwen_dashscope_results_clean.json"
with open(CLEAN_JSON_PATH, "w", encoding="utf-8") as f:
    json.dump(clean_results, f, indent=2, ensure_ascii=False)

print(f"Clean results saved to {CLEAN_JSON_PATH}. {len(clean_results)} entries remain.")

# Count entries by type
no_error_count = sum(1 for r in clean_results if not r.get("error"))
data_inspection_count = sum(
    1
    for r in clean_results
    if r.get("error") and "data_inspection_failed" in r.get("error", "")
)

print(f"  - {no_error_count} successful entries")
print(f"  - {data_inspection_count} entries with 'data_inspection_failed' error")

# Get all processed URLs from the clean results
processed_urls = set(r["video_url"] for r in clean_results if "video_url" in r)

# Remove processed URLs from your video_urls_list
video_urls_list = [url for url in video_urls_list if url not in processed_urls]

print(f"{len(video_urls_list)} URLs remain to process.")
# Out:
# Clean results saved to ../../data/results/qwen_dashscope_results_clean.json. 3894 entries remain.
#   - 3654 successful entries
#   - 240 entries with 'data_inspection_failed' error
# 56 URLs remain to process.

# %%
qwen_model.parse_and_save_transcripts(
    input_json_path="../../data/results/qwen_dashscope_results_clean.json",
    output_json_path="../../data/results/qwen_dashscope_transcripts_final.json",
    metadata_json_path=QWEN_METADATA_OUTPUT_JSON_PATH,
)
